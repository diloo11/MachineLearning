# %%
# %pip install pyprep
# Out:
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.5 MB 6.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.2/7.5 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 5.2/7.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 5.6 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [pooch]
#    ---------------------------------------- 0/3 [pooch]
#    ---------------------------------------- 0/3 [pooch]
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
#    ------------- -------------------------- 1/3 [mne]
# ...

# %%
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install wandb
# Out:
# ...
#    ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.0 MB 354.7 kB/s eta 0:01:15
#     --------------------------------------- 0.5/27.0 MB 354.7 kB/s eta 0:01:15
#     --------------------------------------- 0.5/27.0 MB 354.7 kB/s eta 0:01:15
#     --------------------------------------- 0.5/27.0 MB 354.7 kB/s eta 0:01:15
# ...

# %%
# %pip install pyecg
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# %pip install -q pandas matplotlib numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
